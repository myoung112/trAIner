# %%
import os
import shutil
import random
import math

exer = ['BicycleCrunch']
        #'BurpeeTest', 
        #'CrossLunge', 
        #'Crunch', 
        #'Flank', 
        #'Goodmorning', 
        #'HipThrust', 
        #'KneePushup', 
        #'LyingLegRaise', 
        #'Pushup', 
        #'ScissorCross', 
        #'StandingKneeUp', 
        #'StandingSideCrunch', 
        #'StepBackwardDynamicLunge', 
        #'StepForwardDynamicLunge']

for exercise in exer:
    # 원본 폴더와 대상 폴더 경로 설정
    source_folder = f'E:\\AI\\dataset_skeleton_for_gen\\face\\training'
    valid_folder = f'E:\\AI\\dataset_skeleton_for_gen\\face\\validation'
    test_folder = f'E:\\AI\\dataset_skeleton_for_gen\\face\\test'
    
    path = []
    
    for item in os.listdir(source_folder):
        path.append(item)
    
    # 원본 폴더에서 .jpg 파일만 리스트로 가져오기
    for exe in path:
        source = os.path.join(source_folder, exe)
        valid = os.path.join(valid_folder, exe)
        test = os.path.join(test_folder, exe)
        
        # 검증(validation) 및 테스트(test) 폴더가 없으면 생성
        os.makedirs(valid, exist_ok=True)
        os.makedirs(test, exist_ok=True)
        
        files = [file for file in os.listdir(source) if file.endswith('.jpg')]
        
        total_files_count = len(files)
        sample_size = math.ceil(total_files_count * 0.3)  # 전체 파일의 30% 계산
        valid_test_size = math.ceil(sample_size * 0.5)  # 선택된 파일의 50% 계산 (전체의 15%)
    
        if total_files_count < sample_size:
            print("Error: 원본 폴더에 필요한 만큼의 .jpg 파일이 없습니다.")
        else:
            # 파일을 무작위로 선택하여 30% 리스트 생성
            selected_files = random.sample(files, sample_size)
            
            # 검증(validation) 폴더로 이동할 파일 선택
            valid_files = selected_files[:valid_test_size]
            
            # 테스트(test) 폴더로 이동할 파일 선택
            test_files = selected_files[valid_test_size:2*valid_test_size]
            
            # 선택된 파일을 검증(validation) 폴더로 이동
            for file in valid_files:
                shutil.move(os.path.join(source, file), os.path.join(valid, file))
            
            # 선택된 파일을 테스트(test) 폴더로 이동
            for file in test_files:
                shutil.move(os.path.join(source, file), os.path.join(test, file))
            
            print(f"{len(valid_files)}개의 파일이 검증(validation) 폴더로, {len(test_files)}개의 파일이 테스트(test) 폴더로 이동되었습니다.")
# Out:
# 133개의 파일이 검증(validation) 폴더로, 133개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 132개의 파일이 검증(validation) 폴더로, 132개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 138개의 파일이 검증(validation) 폴더로, 138개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 137개의 파일이 검증(validation) 폴더로, 136개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 139개의 파일이 검증(validation) 폴더로, 138개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 131개의 파일이 검증(validation) 폴더로, 131개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 134개의 파일이 검증(validation) 폴더로, 133개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 140개의 파일이 검증(validation) 폴더로, 139개의 파일이 테스트(test) 폴더로 이동되었습니다.

# %%
import os
import shutil
import random
import math

exer = ['BicycleCrunch',
        'BurpeeTest', 
        'CrossLunge', 
        'Crunch', 
        'Flank', 
        'Goodmorning', 
        'HipThrust', 
        'KneePushup', 
        'LyingLegRaise', 
        'Pushup', 
        'ScissorCross', 
        'StandingKneeUp', 
        'StandingSideCrunch', 
        'StepBackwardDynamicLunge', 
        'StepForwardDynamicLunge']

for exercise in exer:
    # 원본 폴더와 대상 폴더 경로 설정
    source_folder = f'E:\\AI\\dataset_skeleton_sep\\side\\{exercise}\\training'
    valid_folder = f'E:\\AI\\dataset_skeleton_sep\\side\\{exercise}\\validation'
    test_folder = f'E:\\AI\\dataset_skeleton_sep\\side\\{exercise}\\test'
    
    path = []
    
    for item in os.listdir(source_folder):
        path.append(item)
    
    # 원본 폴더에서 .jpg 파일만 리스트로 가져오기
    for exe in path:
        source = os.path.join(source_folder, exe)
        valid = os.path.join(valid_folder, exe)
        test = os.path.join(test_folder, exe)
        
        # 검증(validation) 및 테스트(test) 폴더가 없으면 생성
        os.makedirs(valid, exist_ok=True)
        os.makedirs(test, exist_ok=True)
        
        files = [file for file in os.listdir(source) if file.endswith('.jpg')]
        
        total_files_count = len(files)
        sample_size = math.ceil(total_files_count * 0.3)  # 전체 파일의 30% 계산
        valid_test_size = math.ceil(sample_size * 0.5)  # 선택된 파일의 50% 계산 (전체의 15%)
    
        if total_files_count < sample_size:
            print("Error: 원본 폴더에 필요한 만큼의 .jpg 파일이 없습니다.")
        else:
            # 파일을 무작위로 선택하여 30% 리스트 생성
            selected_files = random.sample(files, sample_size)
            
            # 검증(validation) 폴더로 이동할 파일 선택
            valid_files = selected_files[:valid_test_size]
            
            # 테스트(test) 폴더로 이동할 파일 선택
            test_files = selected_files[valid_test_size:2*valid_test_size]
            
            # 선택된 파일을 검증(validation) 폴더로 이동
            for file in valid_files:
                shutil.move(os.path.join(source, file), os.path.join(valid, file))
            
            # 선택된 파일을 테스트(test) 폴더로 이동
            for file in test_files:
                shutil.move(os.path.join(source, file), os.path.join(test, file))
            
            print(f"{len(valid_files)}개의 파일이 검증(validation) 폴더로, {len(test_files)}개의 파일이 테스트(test) 폴더로 이동되었습니다.")
# Out:
# 209개의 파일이 검증(validation) 폴더로, 209개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 206개의 파일이 검증(validation) 폴더로, 206개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 210개의 파일이 검증(validation) 폴더로, 210개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 204개의 파일이 검증(validation) 폴더로, 204개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 214개의 파일이 검증(validation) 폴더로, 213개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 209개의 파일이 검증(validation) 폴더로, 209개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 209개의 파일이 검증(validation) 폴더로, 208개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 209개의 파일이 검증(validation) 폴더로, 208개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 246개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 246개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 246개의 파일이 검증(validation) 폴더로, 246개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 252개의 파일이 검증(validation) 폴더로, 251개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 246개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 242개의 파일이 검증(validation) 폴더로, 241개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 244개의 파일이 검증(validation) 폴더로, 244개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 246개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 244개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 218개의 파일이 검증(validation) 폴더로, 218개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 214개의 파일이 검증(validation) 폴더로, 214개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 219개의 파일이 검증(validation) 폴더로, 219개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 220개의 파일이 검증(validation) 폴더로, 219개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 215개의 파일이 검증(validation) 폴더로, 214개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 216개의 파일이 검증(validation) 폴더로, 216개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 216개의 파일이 검증(validation) 폴더로, 215개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 218개의 파일이 검증(validation) 폴더로, 218개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 220개의 파일이 검증(validation) 폴더로, 219개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 217개의 파일이 검증(validation) 폴더로, 217개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 217개의 파일이 검증(validation) 폴더로, 216개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 210개의 파일이 검증(validation) 폴더로, 209개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 215개의 파일이 검증(validation) 폴더로, 215개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 215개의 파일이 검증(validation) 폴더로, 215개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 209개의 파일이 검증(validation) 폴더로, 208개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 54개의 파일이 검증(validation) 폴더로, 54개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 51개의 파일이 검증(validation) 폴더로, 50개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 42개의 파일이 검증(validation) 폴더로, 42개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 55개의 파일이 검증(validation) 폴더로, 55개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 49개의 파일이 검증(validation) 폴더로, 49개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 38개의 파일이 검증(validation) 폴더로, 37개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 58개의 파일이 검증(validation) 폴더로, 57개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 57개의 파일이 검증(validation) 폴더로, 56개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 196개의 파일이 검증(validation) 폴더로, 195개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 195개의 파일이 검증(validation) 폴더로, 195개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 192개의 파일이 검증(validation) 폴더로, 192개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 192개의 파일이 검증(validation) 폴더로, 192개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 194개의 파일이 검증(validation) 폴더로, 193개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 194개의 파일이 검증(validation) 폴더로, 193개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 196개의 파일이 검증(validation) 폴더로, 196개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 225개의 파일이 검증(validation) 폴더로, 225개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 224개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 221개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 215개의 파일이 검증(validation) 폴더로, 214개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 147개의 파일이 검증(validation) 폴더로, 146개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 144개의 파일이 검증(validation) 폴더로, 144개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 132개의 파일이 검증(validation) 폴더로, 132개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 144개의 파일이 검증(validation) 폴더로, 144개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 127개의 파일이 검증(validation) 폴더로, 127개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 152개의 파일이 검증(validation) 폴더로, 152개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 141개의 파일이 검증(validation) 폴더로, 141개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 158개의 파일이 검증(validation) 폴더로, 157개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 131개의 파일이 검증(validation) 폴더로, 130개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 156개의 파일이 검증(validation) 폴더로, 156개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 134개의 파일이 검증(validation) 폴더로, 134개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 125개의 파일이 검증(validation) 폴더로, 124개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 137개의 파일이 검증(validation) 폴더로, 136개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 147개의 파일이 검증(validation) 폴더로, 147개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 159개의 파일이 검증(validation) 폴더로, 159개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 139개의 파일이 검증(validation) 폴더로, 139개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 142개의 파일이 검증(validation) 폴더로, 142개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 126개의 파일이 검증(validation) 폴더로, 126개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 150개의 파일이 검증(validation) 폴더로, 150개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 133개의 파일이 검증(validation) 폴더로, 132개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 149개의 파일이 검증(validation) 폴더로, 148개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 160개의 파일이 검증(validation) 폴더로, 160개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 147개의 파일이 검증(validation) 폴더로, 146개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 147개의 파일이 검증(validation) 폴더로, 147개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 128개의 파일이 검증(validation) 폴더로, 128개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 146개의 파일이 검증(validation) 폴더로, 145개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 142개의 파일이 검증(validation) 폴더로, 141개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 163개의 파일이 검증(validation) 폴더로, 163개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 146개의 파일이 검증(validation) 폴더로, 145개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 155개의 파일이 검증(validation) 폴더로, 155개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 151개의 파일이 검증(validation) 폴더로, 151개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 158개의 파일이 검증(validation) 폴더로, 157개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 215개의 파일이 검증(validation) 폴더로, 214개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 214개의 파일이 검증(validation) 폴더로, 213개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 221개의 파일이 검증(validation) 폴더로, 220개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 221개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 218개의 파일이 검증(validation) 폴더로, 217개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 224개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 224개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 224개의 파일이 검증(validation) 폴더로, 224개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 225개의 파일이 검증(validation) 폴더로, 224개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 221개의 파일이 검증(validation) 폴더로, 221개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 226개의 파일이 검증(validation) 폴더로, 225개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 219개의 파일이 검증(validation) 폴더로, 219개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 147개의 파일이 검증(validation) 폴더로, 147개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 146개의 파일이 검증(validation) 폴더로, 146개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 129개의 파일이 검증(validation) 폴더로, 128개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 145개의 파일이 검증(validation) 폴더로, 144개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 128개의 파일이 검증(validation) 폴더로, 128개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 157개의 파일이 검증(validation) 폴더로, 156개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 148개의 파일이 검증(validation) 폴더로, 148개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 151개의 파일이 검증(validation) 폴더로, 151개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 130개의 파일이 검증(validation) 폴더로, 129개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 152개의 파일이 검증(validation) 폴더로, 152개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 130개의 파일이 검증(validation) 폴더로, 129개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 113개의 파일이 검증(validation) 폴더로, 113개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 146개의 파일이 검증(validation) 폴더로, 146개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 149개의 파일이 검증(validation) 폴더로, 149개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 170개의 파일이 검증(validation) 폴더로, 170개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 144개의 파일이 검증(validation) 폴더로, 144개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 153개의 파일이 검증(validation) 폴더로, 152개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 137개의 파일이 검증(validation) 폴더로, 136개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 155개의 파일이 검증(validation) 폴더로, 154개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 127개의 파일이 검증(validation) 폴더로, 127개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 146개의 파일이 검증(validation) 폴더로, 145개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 163개의 파일이 검증(validation) 폴더로, 163개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 151개의 파일이 검증(validation) 폴더로, 150개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 152개의 파일이 검증(validation) 폴더로, 151개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 119개의 파일이 검증(validation) 폴더로, 118개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 150개의 파일이 검증(validation) 폴더로, 150개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 150개의 파일이 검증(validation) 폴더로, 149개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 154개의 파일이 검증(validation) 폴더로, 153개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 138개의 파일이 검증(validation) 폴더로, 137개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 143개의 파일이 검증(validation) 폴더로, 143개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 119개의 파일이 검증(validation) 폴더로, 118개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 152개의 파일이 검증(validation) 폴더로, 151개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 224개의 파일이 검증(validation) 폴더로, 224개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 225개의 파일이 검증(validation) 폴더로, 224개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 225개의 파일이 검증(validation) 폴더로, 225개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 225개의 파일이 검증(validation) 폴더로, 225개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 224개의 파일이 검증(validation) 폴더로, 224개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 217개의 파일이 검증(validation) 폴더로, 216개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 220개의 파일이 검증(validation) 폴더로, 220개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 221개의 파일이 검증(validation) 폴더로, 221개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 216개의 파일이 검증(validation) 폴더로, 215개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 213개의 파일이 검증(validation) 폴더로, 213개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 217개의 파일이 검증(validation) 폴더로, 216개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 220개의 파일이 검증(validation) 폴더로, 219개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 216개의 파일이 검증(validation) 폴더로, 216개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 221개의 파일이 검증(validation) 폴더로, 220개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 221개의 파일이 검증(validation) 폴더로, 221개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 219개의 파일이 검증(validation) 폴더로, 219개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 224개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 222개의 파일이 검증(validation) 폴더로, 222개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 218개의 파일이 검증(validation) 폴더로, 217개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 213개의 파일이 검증(validation) 폴더로, 213개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 214개의 파일이 검증(validation) 폴더로, 214개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 223개의 파일이 검증(validation) 폴더로, 223개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 220개의 파일이 검증(validation) 폴더로, 220개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 219개의 파일이 검증(validation) 폴더로, 218개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 210개의 파일이 검증(validation) 폴더로, 210개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 244개의 파일이 검증(validation) 폴더로, 244개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 244개의 파일이 검증(validation) 폴더로, 244개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 244개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 243개의 파일이 검증(validation) 폴더로, 243개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 247개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 244개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 244개의 파일이 검증(validation) 폴더로, 243개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 192개의 파일이 검증(validation) 폴더로, 192개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 197개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 197개의 파일이 검증(validation) 폴더로, 196개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 248개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 250개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 248개의 파일이 검증(validation) 폴더로, 247개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 245개의 파일이 검증(validation) 폴더로, 245개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 249개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.
# 250개의 파일이 검증(validation) 폴더로, 249개의 파일이 테스트(test) 폴더로 이동되었습니다.

# %%
for exe in path:
    source = os.path.join(source_folder, exe)
    test = os.path.join(valid_folder, exe)
    print(source)
    print(test)
    files = [file for file in os.listdir(source) if file.endswith('.jpg')]
    
    if len(files) < 300:
        print("Error: 원본 폴더에 .jpg 파일이 300개 미만입니다.")
    else:
        # 파일을 무작위로 선택하여 300개 리스트 생성
        selected_files = random.sample(files, 3400)
    
        # 선택된 파일을 대상 폴더로 이동
        for file in selected_files:
            shutil.move(os.path.join(source, file), os.path.join(test, file))
        
        print("파일 이동이 완료되었습니다.")
