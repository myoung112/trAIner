# %%
import os
import shutil

# 원본 디렉토리
source_dir = r"E:\AI\dataset_skeleton\training\face"
des_dir = r'E:\AI\dataset_skeleton_for_generator_all\face\training'
# os.walk를 이용해 모든 하위 디렉토리 탐색
for roots, dirs, files in os.walk(source_dir):
    for file in files:
        # 파일 확장자가 .jpg인 경우
        if file.endswith('.jpg'):
            # 원본 파일 경로
            source_file_path = os.path.join(roots, file)

            num = file[0:3]
            source_path1, _ = os.path.split(roots)
            source_path2, _ = os.path.split(source_path1)
            source_path, exercise = os.path.split(source_path2)
            # 목적지 파일 경로 
            des_path = os.path.join(des_dir, f'{exercise}_{num}')
             
            #destination_file_path = os.path.join(des_path, file)

            # 경로가 없으면 만들어라
            if not os.path.exists(des_path):
                os.makedirs(des_path)
            
            # 파일 복사
            shutil.copy(source_file_path, des_path)

print("모든 .jpg 파일 복사 완료.")
# Out:
# 모든 .jpg 파일 복사 완료.

# %%
import os
import shutil

# 원본 디렉토리
source_dir = r"E:\AI\dataset_skeleton\validation\face"
des_dir = r'E:\AI\dataset_skeleton_for_generator_all\face\training'
# os.walk를 이용해 모든 하위 디렉토리 탐색
for roots, dirs, files in os.walk(source_dir):
    for file in files:
        # 파일 확장자가 .jpg인 경우
        if file.endswith('.jpg'):
            # 원본 파일 경로
            source_file_path = os.path.join(roots, file)

            num = file[0:3]
            source_path1, _ = os.path.split(roots)
            source_path2, _ = os.path.split(source_path1)
            source_path, exercise = os.path.split(source_path2)
            # 목적지 파일 경로 
            des_path = os.path.join(des_dir, f'{exercise}_{num}')
             
            #destination_file_path = os.path.join(des_path, file)

            # 경로가 없으면 만들어라
            if not os.path.exists(des_path):
                os.makedirs(des_path)
            
            # 파일 복사
            shutil.copy(source_file_path, des_path)

print("모든 .jpg 파일 복사 완료.")
# Out:
# 모든 .jpg 파일 복사 완료.

# %%
import os
import shutil

# 원본 디렉토리
source_dir = r"E:\AI\dataset_skeleton\training\side"
des_dir = r'E:\AI\dataset_skeleton_for_gen\side\training'
# os.walk를 이용해 모든 하위 디렉토리 탐색
for roots, dirs, files in os.walk(source_dir):
    for file in files:
        # 파일 확장자가 .jpg인 경우
        if file.endswith('.jpg'):
            # 원본 파일 경로
            source_file_path = os.path.join(roots, file)

            num = file[0:3]
            source_path1, _ = os.path.split(roots)
            source_path2, _ = os.path.split(source_path1)
            source_path, exercise = os.path.split(source_path2)
            # 목적지 파일 경로 
            des_path = os.path.join(des_dir, f'{exercise}_{num}')
             
            #destination_file_path = os.path.join(des_path, file)

            # 경로가 없으면 만들어라
            if not os.path.exists(des_path):
                os.makedirs(des_path)            
            
            # 파일 복사
            shutil.copy(source_file_path, des_path)

print("모든 .jpg 파일 복사 완료.")
# Out:
# 모든 .jpg 파일 복사 완료.

# %%
import os
import shutil

# 원본 디렉토리
source_dir = r"E:\AI\dataset_skeleton\validation\side"
des_dir = r'E:\AI\dataset_skeleton_for_gen\side\training'
# os.walk를 이용해 모든 하위 디렉토리 탐색
for roots, dirs, files in os.walk(source_dir):
    for file in files:
        # 파일 확장자가 .jpg인 경우
        if file.endswith('.jpg'):
            # 원본 파일 경로
            source_file_path = os.path.join(roots, file)

            num = file[0:3]
            source_path1, _ = os.path.split(roots)
            source_path2, _ = os.path.split(source_path1)
            source_path, exercise = os.path.split(source_path2)
            # 목적지 파일 경로 
            des_path = os.path.join(des_dir, f'{exercise}_{num}')
             
            #destination_file_path = os.path.join(des_path, file)

            # 경로가 없으면 만들어라
            if not os.path.exists(des_path):
                os.makedirs(des_path)
            
            
            # 파일 복사
            shutil.copy(source_file_path, des_path)

print("모든 .jpg 파일 복사 완료.")
# Out:
# 모든 .jpg 파일 복사 완료.
