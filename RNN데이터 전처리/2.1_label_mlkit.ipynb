# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day01'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day01'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day02'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day02'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day05'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day05'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day09'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day09'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day10'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day10'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day13'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day13'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day14'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day14'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day23'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day23'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day24'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day24'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day27'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day27'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day28'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day28'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day33'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day33'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day34'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day34'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day35'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day35'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done

# %%
#model_1 transform 61번까지 3920*2160이길래 따로 전처리
import os
import json

# JSON 데이터의 상위 폴더
json_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data\\Day36'
out_path = 'E:\\AInotes\\자세교정\\RNN데이터 전처리\\keypoint\\label_data_mlkit\\Day36'


def delete_keypoint(json_path, output_path):
    # JSON 파일 로드
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data_list = json.load(json_file)
        for data in data_list:
            for key in keys_to_remove:
                if key in data['pts']:
                    del data['pts'][key]
            
    # 결과 JSON 파일 저장
        _, file_name = os.path.split(json_path)
        filename_without_extension, _ = os.path.splitext(file_name)
        parts = filename_without_extension.split('_')
        num = parts[-2]
        output_path = os.path.join(out_path, f'model_{num}_mlkit.json')
        with open(output_path, 'w', encoding='utf-8') as output_file:
            json.dump(data_list, output_file, ensure_ascii=False, indent=4)

keys_to_remove = ['Neck_x', 'Neck_y', 'Back_x', 'Back_y', 'Waist_x', 'Waist_y', 'Left Palm_x', 'Left Palm_y', 'Right Palm_x', 'Right Palm_y']

for data in os.listdir(json_path):
    data_path = os.path.join(json_path, data)
    if os.path.isfile(data_path) and data_path.endswith('.json'):
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        delete_keypoint(data_path, out_path)
# pts 내에서 지정된 키들을 제거
print('done')
# Out:
# done
